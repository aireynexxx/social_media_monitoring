# %%
import pandas as pd
import numpy as np

df = pd.read_csv('insta_comments.csv')
df = df.iloc[:50]
df
# Out:
#    article_id     source                                            comment  \
# 0     insta_3  instagram  Какая прелесть, у меня тоже к этому ровд есть ...
# 1     insta_4  instagram              Кому то захотелось это место! 100%!🙌🙌
# 2     insta_5  instagram                                     Так неожиданно
# 3     insta_6  instagram                                  Кулиб кулиб скяди
# 4     insta_7  instagram  😂eng qizig'i yangilik ilovasida Franklinni qar...
# 5     insta_8  instagram  👏👏👏отлично подставили ! Место нужно было , вот...
# 6     insta_9  instagram                                    😂😂😂😂 не новость
# 7    insta_10  instagram  Ого-го это как крупное землетрясение вместе св...
# 8    insta_11  instagram  Видимо хотели его с должности снять, вот и сня...
# 9    insta_12  instagram  Напишите про котенка в @rano_eco_village, врем...
# 10   insta_13  instagram                      Даже доллар в хайране на фото
# ...

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# example:
y_true = df['true_sentiment']  # replace with your actual column name
y_pred = df['sentiment']  # replace with your actual column name

# Confusion matrix (will be a 2D array)
cm = confusion_matrix(y_true, y_pred, labels=['positive', 'neutral', 'negative'])
print("Confusion Matrix:\n", cm)

# F1 score (macro-averaged for multi-class)
f1 = f1_score(y_true, y_pred, average='macro')
print("F1 Score (macro):", f1)

# Detailed classification report (includes precision, recall, f1 for each class)
print(classification_report(y_true, y_pred))
# Out:
# Confusion Matrix:
#  [[ 0  1  5]
#  [ 0  5 13]
#  [ 0  7 16]]
# F1 Score (macro): 0.14247881355932204
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#      neutral       0.00      0.00      0.00         1
#     negarive       0.00      0.00      0.00         1
#     negative       0.44      0.70      0.54        23
#      neutral       0.36      0.28      0.31        18
#     positive       0.00      0.00      0.00         6
#
#     accuracy                           0.42        50
#    macro avg       0.13      0.16      0.14        50
# weighted avg       0.33      0.42      0.36        50
# C:\Users\tjwat\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   article_id      50 non-null     object
#  1   source          50 non-null     object
#  2   comment         50 non-null     object
#  3   clean_comment   50 non-null     object
#  4   sentiment       50 non-null     object
#  5   true_sentiment  44 non-null     object
# dtypes: object(6)
# memory usage: 2.5+ KB

# %%
print(df['true_sentiment'].apply(type).value_counts())
print(df['sentiment'].apply(type).value_counts())
# Out:
# true_sentiment
# <class 'str'>      44
# <class 'float'>     6
# Name: count, dtype: int64
# sentiment
# <class 'str'>    50
# Name: count, dtype: int64

# %%
print(df['true_sentiment'].isna().sum())
print(df['sentiment'].isna().sum())
# Out:
# 6
# 0

# %%
# Option A: drop rows with missing or invalid labels
df_clean = df.dropna(subset=['true_sentiment', 'sentiment'])

# Option B: fill NaNs with a default class or string (not ideal for eval)
df['true_sentiment'] = df['true_sentiment'].fillna('neutral')
df['sentiment'] = df['sentiment'].fillna('neutral')

# %%
df['true_sentiment'] = df['true_sentiment'].astype(str)
df['sentiment'] = df['sentiment'].astype(str)
